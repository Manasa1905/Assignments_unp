# %% [markdown]
# <a href="https://colab.research.google.com/github/Manasa1905/Assignments_unp/blob/main/module1_revision_16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pt
import seaborn as sns
sns.set(color_codes=True)
import datetime

# %% [markdown]
# IMPORTING THE DATA SET

# %%
dt=pd.read_excel("/content/Housing.xlsx")
dt
# Out:
#        UniqueID                   LandUse  \
# 0           2045            SINGLE FAMILY
# 1          16918            SINGLE FAMILY
# 2          54582            SINGLE FAMILY
# 3          43070            SINGLE FAMILY
# 4          22714            SINGLE FAMILY
# ...          ...                      ...
# 56472      30469            SINGLE FAMILY
# 56473      27707            SINGLE FAMILY
# 56474      52709  VACANT RESIDENTIAL LAND
# 56475      54042  VACANT RESIDENTIAL LAND
# 56476      54043  VACANT RESIDENTIAL LAND
#
#                            PropertyAddress   SaleDate  SalePrice  Acre  \
# 0       1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000   2.3
# 1       1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10     366000   3.5
# 2       1864 FOX CHASE  DR, GOODLETTSVILLE 2016-09-26     435000   2.9
# 3       1853  FOX CHASE DR, GOODLETTSVILLE 2016-01-29     255000   2.6
# 4       1829  FOX CHASE DR, GOODLETTSVILLE 2014-10-10     278000   2.0
# ...

# %% [markdown]
# Replace the missing values with appropriate approximations

# %%
dt['Acre'].fillna(np.mean(dt["Acre"]),inplace=True)
dt['LandValue'].fillna(np.mean(dt["LandValue"]),inplace=True)
dt['BuildingValue'].fillna(np.mean(dt["BuildingValue"]),inplace=True)
dt['TotalValue'].fillna(np.mean(dt["TotalValue"]),inplace=True)
dt['YearBuilt'].fillna(np.mean(dt["YearBuilt"]),inplace=True)
dt['Bedrooms'].fillna(np.mean(dt["Bedrooms"]),inplace=True)
dt['FullBath'].fillna(np.mean(dt["FullBath"]),inplace=True)
dt['HalfBath'].fillna(np.mean(dt["HalfBath"]),inplace=True)
dt
# Out:
#        UniqueID                   LandUse  \
# 0           2045            SINGLE FAMILY
# 1          16918            SINGLE FAMILY
# 2          54582            SINGLE FAMILY
# 3          43070            SINGLE FAMILY
# 4          22714            SINGLE FAMILY
# ...          ...                      ...
# 56472      30469            SINGLE FAMILY
# 56473      27707            SINGLE FAMILY
# 56474      52709  VACANT RESIDENTIAL LAND
# 56475      54042  VACANT RESIDENTIAL LAND
# 56476      54043  VACANT RESIDENTIAL LAND
#
#                            PropertyAddress   SaleDate  SalePrice      Acre  \
# 0       1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000  2.300000
# 1       1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10     366000  3.500000
# 2       1864 FOX CHASE  DR, GOODLETTSVILLE 2016-09-26     435000  2.900000
# 3       1853  FOX CHASE DR, GOODLETTSVILLE 2016-01-29     255000  2.600000
# 4       1829  FOX CHASE DR, GOODLETTSVILLE 2014-10-10     278000  2.000000
# ...

# %%
dt.isna()
# Out:
#        UniqueID   LandUse  PropertyAddress  SaleDate  SalePrice   Acre  \
# 0          False    False            False     False      False  False
# 1          False    False            False     False      False  False
# 2          False    False            False     False      False  False
# 3          False    False            False     False      False  False
# 4          False    False            False     False      False  False
# ...          ...      ...              ...       ...        ...    ...
# 56472      False    False            False     False      False  False
# 56473      False    False            False     False      False  False
# 56474      False    False            False     False      False  False
# 56475      False    False            False     False      False  False
# 56476      False    False            False     False      False  False
#
#        LandValue  BuildingValue  TotalValue  YearBuilt  Bedrooms  FullBath  \
# ...

# %% [markdown]
# Rename the columns to better suited names

# %%
dt.rename(columns={"PropertyAddress":"PropAddr"},inplace=True)
dt.rename(columns={"SalePrice":"SalesPrice"},inplace=True)
dt.rename(columns={"Bedrooms":"Number_of_Bedrooms"},inplace=True)

# %%
dt
# Out:
#        UniqueID                   LandUse  \
# 0           2045            SINGLE FAMILY
# 1          16918            SINGLE FAMILY
# 2          54582            SINGLE FAMILY
# 3          43070            SINGLE FAMILY
# 4          22714            SINGLE FAMILY
# ...          ...                      ...
# 56472      30469            SINGLE FAMILY
# 56473      27707            SINGLE FAMILY
# 56474      52709  VACANT RESIDENTIAL LAND
# 56475      54042  VACANT RESIDENTIAL LAND
# 56476      54043  VACANT RESIDENTIAL LAND
#
#                                   PropAddr   SaleDate  SalesPrice      Acre  \
# 0       1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09      240000  2.300000
# 1       1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10      366000  3.500000
# 2       1864 FOX CHASE  DR, GOODLETTSVILLE 2016-09-26      435000  2.900000
# 3       1853  FOX CHASE DR, GOODLETTSVILLE 2016-01-29      255000  2.600000
# ...

# %% [markdown]
# Extract the month and year from the sale date.

# %%
dt['month'] = dt['SaleDate'].dt.month
dt['month']
# Out:
# 0         4
# 1         6
# 2         9
# 3         1
# 4        10
#          ..
# 56472     5
# 56473     3
# 56474     8
# 56475     9
# 56476     9
# Name: month, Length: 56477, dtype: int64

# %%
dt['year'] = dt['SaleDate'].dt.year
dt['year']
dt
# Out:
#        UniqueID                   LandUse  \
# 0           2045            SINGLE FAMILY
# 1          16918            SINGLE FAMILY
# 2          54582            SINGLE FAMILY
# 3          43070            SINGLE FAMILY
# 4          22714            SINGLE FAMILY
# ...          ...                      ...
# 56472      30469            SINGLE FAMILY
# 56473      27707            SINGLE FAMILY
# 56474      52709  VACANT RESIDENTIAL LAND
# 56475      54042  VACANT RESIDENTIAL LAND
# 56476      54043  VACANT RESIDENTIAL LAND
#
#                                   PropAddr   SaleDate  SalesPrice      Acre  \
# 0       1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09      240000  2.300000
# 1       1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10      366000  3.500000
# 2       1864 FOX CHASE  DR, GOODLETTSVILLE 2016-09-26      435000  2.900000
# 3       1853  FOX CHASE DR, GOODLETTSVILLE 2016-01-29      255000  2.600000
# ...

# %% [markdown]
# Extract the pin number from the property address

# %%
i=0
s=dt.PropAddr
for i in range (len(s)):
  p=s[i]
  print(p[0:4])
# Out:
# 1808
# 1832
# 1864
# 1853
# 1829
# 1821
# 2005
# 1917
# 1428
# 1420
# 2209
# 109
# 1900
# 629
# 633
# 637
# 1976
# 644
# 1921
# 1916
# 2050
# 2034
# 811
# 331
# 361
# 119
# 8154
# 8158
# 8136
# 1334
# 1412
# 612
# 2013
# 600
# 604
# 609
# 621
# 613
# 3128
# 7515
# 7620
# 7624
# 7628
# 3113
# 3113
# 3117
# 3107
# 3124
# 2466
# 7221
# 7104
# 7143
# 7175
# 6912
# 334
# 330
# 0  B
# 0  B
# 235
# 522
# 332
# 332
# 314
# 312
# 408
# 410
# 207
# 203
# 208
# 202
# 203
# 110
# 103
# 204
# 202
# 202
# 507
# 511
# 508
# 107
# 502
# 605
# 205
# 105
# 105
# 301
# 301
# 316
# 316
# 407
# 402
# 401
# 105
# 105
# 102
# 227
# 207
# 214
# 504
# 232
# 202
# 205
# 207
# 108
# 304
# 305
# 308
# 300
# 105
# 108
# 336
# 105
# 105
# 111
# 112
# 104
# 102
# 318
# 331
# 371
# 383
# 391
# 397
# 539
# 407
# 335
# 335
# 225
# 408
# 119
# 119
# 7507
# 1128
# DICK
# 0  M
# 501
# 517
# 463
# 423
# 435
# 207
# 207
# 220
# 210
# 231
# 244
# 308
# 310
# 104
# 104
# 101
# 409
# 407
# 407
# 313
# 401
# 405
# 413
# 410
# ...

# %%
dt['pin']=dt['PropAddr'].str[:4]
dt['pin']
# Out:
# 0        1808
# 1        1832
# 2        1864
# 3        1853
# 4        1829
#          ...
# 56472    1435
# 56473    1423
# 56474    1804
# 56475    1709
# 56476    1713
# Name: pin, Length: 56477, dtype: object

# %% [markdown]
# Use appropriate plots and functions to answer the following questions.
#
# 1.How has the price of properties changed over the years

# %%
c=dt.groupby("year")["SalesPrice"].count()
sns.barplot(x=c.index,y=c.values)

# %% [markdown]
# 2.Does a specific month or span of months have the highest property prices?

# %%
c=dt.groupby("month")["SalesPrice"].count()
sns.barplot(x=c.index,y=c.values)

# %% [markdown]
# 3.For what purpose were the properties generally purchased

# %%
c=dt.groupby("LandUse")["LandUse"].count()
c
# Out:
# LandUse
# APARTMENT: LOW RISE (BUILT SINCE 1960)            2
# CHURCH                                           34
# CLUB/UNION HALL/LODGE                             1
# CONDO                                           247
# CONDOMINIUM OFC  OR OTHER COM CONDO              35
# CONVENIENCE MARKET WITHOUT GAS                    1
# DAY CARE CENTER                                   2
# DORMITORY/BOARDING HOUSE                         19
# DUPLEX                                         1373
# FOREST                                           10
# GREENBELT                                        10
# GREENBELT/RES_x000D_\nGRRENBELT/RES               3
# LIGHT MANUFACTURING                               1
# METRO OTHER THAN OFC, SCHOOL,HOSP, OR PARK        1
# MOBILE HOME                                      20
# MORTUARY/CEMETERY                                 1
# NIGHTCLUB/LOUNGE                                  1
# NON-PROFIT CHARITABLE SERVICE                     2
# ...

# %%
sns.barplot(x=c.index,y=c.values)

# %% [markdown]
# 4. What is the average age of the properties?

# %%
dt['age']=2022-dt['year']
dt['age']
dt
# Out:
#        UniqueID                   LandUse  \
# 0           2045            SINGLE FAMILY
# 1          16918            SINGLE FAMILY
# 2          54582            SINGLE FAMILY
# 3          43070            SINGLE FAMILY
# 4          22714            SINGLE FAMILY
# ...          ...                      ...
# 56472      30469            SINGLE FAMILY
# 56473      27707            SINGLE FAMILY
# 56474      52709  VACANT RESIDENTIAL LAND
# 56475      54042  VACANT RESIDENTIAL LAND
# 56476      54043  VACANT RESIDENTIAL LAND
#
#                                   PropAddr   SaleDate  SalesPrice      Acre  \
# 0       1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09      240000  2.300000
# 1       1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10      366000  3.500000
# 2       1864 FOX CHASE  DR, GOODLETTSVILLE 2016-09-26      435000  2.900000
# 3       1853  FOX CHASE DR, GOODLETTSVILLE 2016-01-29      255000  2.600000
# ...

# %%
avg=np.median(dt.age)
avg
# Out:
# 7.0

# %% [markdown]
# 5.Have the age of houses affected the price?

# %%
d=dt.groupby("age")["SalesPrice"].count()
d
sns.scatterplot(x=d.index,y=d.values)

# %% [markdown]
# 6. Have the number of rooms in the house affected the price?

# %%
dt['total_number_rooms']=dt['Number_of_Bedrooms']+dt['FullBath']+dt['HalfBath']
dt['total_number_rooms']
# Out:
# 0        6.000000
# 1        8.000000
# 2        7.000000
# 3        6.000000
# 4        7.000000
#            ...
# 56472    5.259848
# 56473    5.259848
# 56474    5.259848
# 56475    5.259848
# 56476    5.259848
# Name: total_number_rooms, Length: 56477, dtype: float64

# %%
i=dt.groupby("total_number_rooms")["SalesPrice"].count()
i

sns.scatterplot(x=i.index, y=i.values)

# %% [markdown]
# 7.Does the size of the property (no. of acres) have any influence in its price?

# %%
i=dt.groupby("Acre")["SalesPrice"].count()
i
sns.scatterplot(x=i.index, y=i.values)

# %% [markdown]
# 8.Are houses located in specific pin numbers expensive over the others?

# %%
g=dt.groupby("pin")["SalesPrice"].count()
g
# Out:
# pin
#   12    1
#   AC    1
#   HA    1
#   LO    2
#   MA    1
#        ..
# STRA    1
# SUNN    1
# TYNE    1
# WASH    2
# WEST    1
# Name: SalesPrice, Length: 6530, dtype: int64

# %%
sns.barplot(x=g.index,y=g.values)

# %% [markdown]
# 9.How have house prices changed in the 21st centuary as supposed to 20th centuary.
